# %%
import os
import random

import numpy as np
import cv2

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.metrics import F1Score
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils.class_weight import compute_class_weight

import matplotlib.pyplot as plt

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# # **[1] Load Data**

# %%
IMAGE_DIR = os.path.join("data", "images")
IMAGE_SIZE = (224, 224)


def load_images(split_dir):
    features, labels, image_paths = [], [], []
    for member_name in sorted(os.listdir(split_dir)):
        member_dir = os.path.join(split_dir, member_name)
        if not os.path.isdir(member_dir):
            continue
        for file_name in os.listdir(member_dir):
            image_path = os.path.join(member_dir, file_name)
            image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
            if image is None:
                continue
            image = cv2.resize(image, IMAGE_SIZE)
            features.append(image.flatten())
            labels.append(member_name)
            image_paths.append(image_path)
    features = np.array(features, dtype=np.float32) / 255.0
    labels = np.array(labels)
    image_paths = np.array(image_paths)
    return features, labels, image_paths


X_train, y_train_label, paths_train = load_images(os.path.join(IMAGE_DIR, "train"))
X_test, y_test_label, paths_test = load_images(os.path.join(IMAGE_DIR, "test"))

print(f"Train: {X_train.shape[0]}, Test: {X_test.shape[0]}, Fitur per data: {X_train.shape[1]}")
print(f"Kelas: {sorted(set(y_train_label))}")
# Out:
# Train: 223, Test: 56, Fitur per data: 50176
# Kelas: ['asta', 'budi', 'juned', 'shabrina']

# %% [markdown]
# # **[2] Preprocessing**

# %% [markdown]
# #### Augmentasi Data (Train Only)

# %%
def augment_image(image):
    variants = []

    # flip horizontal
    variants.append(cv2.flip(image, 1))

    # rotasi kecil (15 derajat)
    height, width = image.shape
    for angle in (-15, 15):
        rotation_matrix = cv2.getRotationMatrix2D((width / 2, height / 2), angle, 1.0)
        variants.append(cv2.warpAffine(image, rotation_matrix, (width, height), borderMode=cv2.BORDER_REPLICATE))

    # brightness
    variants.append(cv2.convertScaleAbs(image, alpha=1.2, beta=15))
    variants.append(cv2.convertScaleAbs(image, alpha=0.8, beta=-15))

    # translasi kecil
    shift_x, shift_y = int(0.05 * width), int(0.05 * height)
    translation_matrix = np.float32([[1, 0, shift_x], [0, 1, shift_y]])
    variants.append(cv2.warpAffine(image, translation_matrix, (width, height), borderMode=cv2.BORDER_REPLICATE))

    return variants


def augment_train_set(image_paths, labels):
    augmented_features, augmented_labels, augmented_paths = [], [], []

    for image_path, label in zip(image_paths, labels):
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        image = cv2.resize(image, IMAGE_SIZE)

        for variant in augment_image(image):
            augmented_features.append(variant.flatten())
            augmented_labels.append(label)
            augmented_paths.append(image_path + " (aug)")

    return (
        np.array(augmented_features, dtype=np.float32) / 255.0,
        np.array(augmented_labels),
        np.array(augmented_paths),
    )


X_train_aug, y_train_label_aug, paths_train_aug = augment_train_set(paths_train, y_train_label)

X_train = np.concatenate([X_train, X_train_aug], axis=0)
y_train_label = np.concatenate([y_train_label, y_train_label_aug], axis=0)
paths_train = np.concatenate([paths_train, paths_train_aug], axis=0)

print(f"Train setelah augmentasi: {X_train.shape[0]} data")
# Out:
# Train setelah augmentasi: 1561 data

# %% [markdown]
# #### Encoding

# %%
label_encoder = LabelEncoder()
label_encoder.fit(y_train_label)

y_train = to_categorical(label_encoder.transform(y_train_label))
y_test = to_categorical(label_encoder.transform(y_test_label))

num_classes = y_train.shape[1]
num_features = X_train.shape[1]

class_weight_values = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(label_encoder.transform(y_train_label)),
    y=label_encoder.transform(y_train_label)
)
class_weight_dict = dict(enumerate(class_weight_values))

print(f"Train: {X_train.shape[0]}, Test: {X_test.shape[0]}")
print(f"Class weight: {class_weight_dict}")
# Out:
# Train: 1561, Test: 56
# Class weight: {0: 0.6558823529411765, 1: 1.8583333333333334, 2: 1.5067567567567568, 3: 0.7852112676056338}

# %% [markdown]
# # **[3] Build Model**

# %%
model = Sequential([
    Dense(128, activation="relu", input_shape=(num_features,)),
    Dropout(0.4),
    Dense(64, activation="relu"),
    Dropout(0.4),
    Dense(32, activation="relu"),
    Dropout(0.2),
    Dense(num_classes, activation="softmax")
])

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=[F1Score(average="macro", name="f1_score")]
)

model.summary()
# Out:
# /Users/faqihfirmanpratama/miniforge3/envs/dbs/lib/python3.11/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-09-07 17:48:26.951256: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2026-09-07 17:48:26.951315: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2026-09-07 17:48:26.951321: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.66 GB
# 2026-09-07 17:48:26.951338: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-09-07 17:48:26.951348: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │     6,422,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,433,124 (24.54 MB)
#  Trainable params: 6,433,124 (24.54 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Training

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=16,
    class_weight=class_weight_dict,
    verbose=1
)
# Out:
# Epoch 1/100
# 2026-09-07 17:48:27.826385: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - f1_score: 0.2845 - loss: 320.2502 - val_f1_score: 0.2294 - val_loss: 20.3633
# Epoch 2/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.3150 - loss: 361.0974 - val_f1_score: 0.4244 - val_loss: 25.0535
# Epoch 3/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - f1_score: 0.3619 - loss: 334.9627 - val_f1_score: 0.6329 - val_loss: 4.3596
# Epoch 4/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - f1_score: 0.4684 - loss: 249.2286 - val_f1_score: 1.0000 - val_loss: 0.0000e+00
# Epoch 5/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.5809 - loss: 149.8613 - val_f1_score: 0.9762 - val_loss: 0.5404
# Epoch 6/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.6817 - loss: 113.2986 - val_f1_score: 0.6329 - val_loss: 25.8960
# Epoch 7/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.7422 - loss: 79.2436 - val_f1_score: 0.9762 - val_loss: 3.2133
# Epoch 8/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.8172 - loss: 59.3819 - val_f1_score: 1.0000 - val_loss: 2.1287e-09
# Epoch 9/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.8468 - loss: 37.7491 - val_f1_score: 0.9762 - val_loss: 3.6622
# Epoch 10/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - f1_score: 0.8696 - loss: 36.5560 - val_f1_score: 0.9762 - val_loss: 6.4476
# Epoch 11/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - f1_score: 0.8705 - loss: 33.2677 - val_f1_score: 0.9762 - val_loss: 1.6916
# Epoch 12/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - f1_score: 0.8968 - loss: 23.8974 - val_f1_score: 1.0000 - val_loss: 0.0000e+00
# Epoch 13/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - f1_score: 0.9155 - loss: 17.7600 - val_f1_score: 1.0000 - val_loss: 0.0000e+00
# Epoch 14/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - f1_score: 0.9204 - loss: 16.5402 - val_f1_score: 0.9762 - val_loss: 0.5555
# Epoch 15/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - f1_score: 0.9210 - loss: 19.5783 - val_f1_score: 0.9762 - val_loss: 2.1129
# Epoch 16/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - f1_score: 0.9083 - loss: 19.1577 - val_f1_score: 0.7673 - val_loss: 14.2917
# Epoch 17/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - f1_score: 0.9341 - loss: 13.3682 - val_f1_score: 0.9762 - val_loss: 3.1364
# Epoch 18/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - f1_score: 0.9483 - loss: 10.1183 - val_f1_score: 0.9762 - val_loss: 8.9222
# Epoch 19/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9415 - loss: 9.9588 - val_f1_score: 0.9762 - val_loss: 0.2796
# Epoch 20/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - f1_score: 0.9546 - loss: 7.6948 - val_f1_score: 1.0000 - val_loss: 0.0000e+00
# Epoch 21/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - f1_score: 0.9633 - loss: 7.2643 - val_f1_score: 0.9484 - val_loss: 3.7785
# Epoch 22/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - f1_score: 0.9578 - loss: 5.8764 - val_f1_score: 1.0000 - val_loss: 0.0000e+00
# Epoch 23/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - f1_score: 0.9456 - loss: 8.7132 - val_f1_score: 0.9762 - val_loss: 1.3972
# Epoch 24/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9440 - loss: 9.5393 - val_f1_score: 0.9762 - val_loss: 1.9745
# Epoch 25/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - f1_score: 0.9477 - loss: 8.9984 - val_f1_score: 0.9762 - val_loss: 17.0813
# Epoch 26/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9476 - loss: 8.9251 - val_f1_score: 0.9762 - val_loss: 16.5117
# Epoch 27/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9450 - loss: 10.1964 - val_f1_score: 0.9762 - val_loss: 6.5892
# Epoch 28/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9517 - loss: 7.5429 - val_f1_score: 1.0000 - val_loss: 0.0000e+00
# Epoch 29/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9575 - loss: 6.8090 - val_f1_score: 0.9762 - val_loss: 0.5814
# Epoch 30/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9600 - loss: 7.2048 - val_f1_score: 1.0000 - val_loss: 0.0000e+00
# Epoch 31/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9483 - loss: 9.3923 - val_f1_score: 0.8646 - val_loss: 15.7886
# Epoch 32/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9459 - loss: 8.5730 - val_f1_score: 0.9762 - val_loss: 9.5464
# Epoch 33/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.9601 - loss: 5.8120 - val_f1_score: 0.9762 - val_loss: 3.7278
# Epoch 34/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - f1_score: 0.9518 - loss: 7.7033 - val_f1_score: 0.9210 - val_loss: 22.2431
# Epoch 35/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - f1_score: 0.9587 - loss: 6.7424 - val_f1_score: 1.0000 - val_loss: 0.0000e+00
# Epoch 36/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - f1_score: 0.9698 - loss: 2.7863 - val_f1_score: 0.9702 - val_loss: 0.2268
# Epoch 37/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - f1_score: 0.9565 - loss: 3.8119 - val_f1_score: 0.9118 - val_loss: 3.4086
# Epoch 38/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - f1_score: 0.9525 - loss: 5.4106 - val_f1_score: 0.9702 - val_loss: 0.1469
# Epoch 39/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - f1_score: 0.9599 - loss: 5.9415 - val_f1_score: 0.9118 - val_loss: 8.6669
# Epoch 40/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9655 - loss: 3.3460 - val_f1_score: 0.9118 - val_loss: 3.4383
# Epoch 41/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - f1_score: 0.9719 - loss: 2.5960 - val_f1_score: 0.9410 - val_loss: 1.1135
# Epoch 42/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - f1_score: 0.9766 - loss: 1.7802 - val_f1_score: 0.9118 - val_loss: 5.2380
# Epoch 43/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - f1_score: 0.9532 - loss: 5.3683 - val_f1_score: 0.9118 - val_loss: 4.4832
# Epoch 44/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - f1_score: 0.9726 - loss: 3.9584 - val_f1_score: 0.9410 - val_loss: 1.1647
# Epoch 45/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.9794 - loss: 1.6719 - val_f1_score: 0.9410 - val_loss: 1.0050
# Epoch 46/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.9665 - loss: 4.0090 - val_f1_score: 0.9410 - val_loss: 1.6335
# Epoch 47/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.9667 - loss: 6.0861 - val_f1_score: 1.0000 - val_loss: 0.0000e+00
# Epoch 48/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.9638 - loss: 5.8217 - val_f1_score: 0.8932 - val_loss: 12.6017
# Epoch 49/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.9638 - loss: 4.1501 - val_f1_score: 1.0000 - val_loss: 0.0000e+00
# Epoch 50/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9754 - loss: 2.6155 - val_f1_score: 0.9118 - val_loss: 6.3605
# Epoch 51/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9732 - loss: 4.3763 - val_f1_score: 0.9261 - val_loss: 9.4039
# Epoch 52/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9765 - loss: 3.2631 - val_f1_score: 0.9210 - val_loss: 24.2785
# Epoch 53/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9591 - loss: 6.3965 - val_f1_score: 0.9484 - val_loss: 0.8205
# Epoch 54/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - f1_score: 0.9717 - loss: 5.2221 - val_f1_score: 1.0000 - val_loss: 0.0000e+00
# Epoch 55/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - f1_score: 0.9687 - loss: 3.1528 - val_f1_score: 0.9118 - val_loss: 8.8398
# Epoch 56/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.9686 - loss: 5.4980 - val_f1_score: 0.8932 - val_loss: 7.3808
# Epoch 57/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.9652 - loss: 5.6886 - val_f1_score: 0.8932 - val_loss: 14.8932
# Epoch 58/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.9848 - loss: 1.9794 - val_f1_score: 0.8932 - val_loss: 24.0434
# Epoch 59/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9763 - loss: 4.0811 - val_f1_score: 0.9118 - val_loss: 7.8434
# Epoch 60/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9773 - loss: 5.9654 - val_f1_score: 0.8932 - val_loss: 12.0071
# Epoch 61/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9790 - loss: 3.2506 - val_f1_score: 0.9210 - val_loss: 18.0544
# Epoch 62/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9732 - loss: 6.2702 - val_f1_score: 0.8932 - val_loss: 20.4498
# Epoch 63/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9827 - loss: 1.5649 - val_f1_score: 0.8932 - val_loss: 17.3734
# Epoch 64/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9812 - loss: 4.1819 - val_f1_score: 0.9210 - val_loss: 7.1278
# Epoch 65/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9821 - loss: 5.0632 - val_f1_score: 0.9410 - val_loss: 6.8292
# Epoch 66/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9653 - loss: 12.2205 - val_f1_score: 0.8932 - val_loss: 22.3264
# Epoch 67/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9681 - loss: 8.0324 - val_f1_score: 0.9118 - val_loss: 11.7104
# Epoch 68/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9770 - loss: 5.3669 - val_f1_score: 0.9118 - val_loss: 16.7197
# Epoch 69/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9915 - loss: 2.4795 - val_f1_score: 0.9118 - val_loss: 25.9153
# Epoch 70/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9884 - loss: 2.3014 - val_f1_score: 0.9118 - val_loss: 13.5851
# Epoch 71/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.9839 - loss: 2.5811 - val_f1_score: 1.0000 - val_loss: 0.0000e+00
# Epoch 72/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.9898 - loss: 1.9215 - val_f1_score: 0.9410 - val_loss: 8.4823
# Epoch 73/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.9872 - loss: 4.0311 - val_f1_score: 0.9410 - val_loss: 2.3119
# Epoch 74/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.9849 - loss: 3.4388 - val_f1_score: 0.8932 - val_loss: 12.2413
# Epoch 75/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - f1_score: 0.9890 - loss: 1.6649 - val_f1_score: 0.9410 - val_loss: 5.1267
# Epoch 76/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - f1_score: 0.9886 - loss: 3.0394 - val_f1_score: 0.9118 - val_loss: 14.0066
# Epoch 77/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - f1_score: 0.9885 - loss: 1.5916 - val_f1_score: 0.9179 - val_loss: 35.6263
# Epoch 78/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9743 - loss: 5.2564 - val_f1_score: 0.9702 - val_loss: 1.5092
# Epoch 79/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9823 - loss: 5.7413 - val_f1_score: 0.9210 - val_loss: 20.2422
# Epoch 80/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9693 - loss: 7.2984 - val_f1_score: 0.9702 - val_loss: 1.4068
# Epoch 81/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.9870 - loss: 4.1439 - val_f1_score: 0.9118 - val_loss: 26.7908
# Epoch 82/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.9911 - loss: 4.1671 - val_f1_score: 0.9410 - val_loss: 10.1904
# Epoch 83/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9943 - loss: 1.6365 - val_f1_score: 0.9118 - val_loss: 13.1888
# Epoch 84/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9869 - loss: 2.3174 - val_f1_score: 0.9118 - val_loss: 39.6672
# Epoch 85/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9872 - loss: 2.5704 - val_f1_score: 0.9179 - val_loss: 21.8842
# Epoch 86/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9833 - loss: 8.4216 - val_f1_score: 0.9118 - val_loss: 28.7172
# Epoch 87/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.9894 - loss: 3.4520 - val_f1_score: 0.8932 - val_loss: 51.0550
# Epoch 88/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9852 - loss: 4.7775 - val_f1_score: 0.8932 - val_loss: 25.4186
# Epoch 89/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9889 - loss: 3.2149 - val_f1_score: 0.9210 - val_loss: 23.2500
# Epoch 90/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9685 - loss: 12.1076 - val_f1_score: 0.9210 - val_loss: 37.4611
# Epoch 91/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.9829 - loss: 5.7030 - val_f1_score: 0.9702 - val_loss: 3.4481
# Epoch 92/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - f1_score: 0.9885 - loss: 4.3419 - val_f1_score: 0.9210 - val_loss: 32.8898
# Epoch 93/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - f1_score: 0.9872 - loss: 3.2553 - val_f1_score: 0.8932 - val_loss: 31.5990
# Epoch 94/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9854 - loss: 7.5568 - val_f1_score: 0.9118 - val_loss: 39.3808
# Epoch 95/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9888 - loss: 2.9178 - val_f1_score: 0.8932 - val_loss: 56.2141
# Epoch 96/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9913 - loss: 2.2013 - val_f1_score: 0.8932 - val_loss: 35.9350
# Epoch 97/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9907 - loss: 6.3351 - val_f1_score: 0.8932 - val_loss: 58.0174
# Epoch 98/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9915 - loss: 3.4465 - val_f1_score: 0.9118 - val_loss: 26.4480
# Epoch 99/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9854 - loss: 5.9555 - val_f1_score: 0.9118 - val_loss: 75.0514
# Epoch 100/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - f1_score: 0.9844 - loss: 6.0834 - val_f1_score: 1.0000 - val_loss: 0.0000e+00

# %% [markdown]
# # **[4] Evaluation**

# %% [markdown]
# #### Learning Curve (F1 Score & Loss)

# %%
fig, (f1_ax, loss_ax) = plt.subplots(1, 2, figsize=(12, 4.5))

epochs_range = range(1, len(history.history["loss"]) + 1)

f1_ax.plot(epochs_range, history.history["f1_score"], label="Train F1", color="navy")
f1_ax.plot(epochs_range, history.history["val_f1_score"], label="Val F1", color="crimson")
f1_ax.set_title("F1 Score per Epoch")
f1_ax.set_xlabel("Epoch")
f1_ax.set_ylabel("F1 Score (macro)")
f1_ax.legend()
f1_ax.grid(alpha=0.3)

loss_ax.plot(epochs_range, history.history["loss"], label="Train Loss", color="navy")
loss_ax.plot(epochs_range, history.history["val_loss"], label="Val Loss", color="crimson")
loss_ax.set_title("Loss per Epoch")
loss_ax.set_xlabel("Epoch")
loss_ax.set_ylabel("Loss")
loss_ax.legend()
loss_ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Evaluasi

# %%
y_test_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
y_test_true = np.argmax(y_test, axis=1)

print(classification_report(y_test_true, y_test_pred, target_names=label_encoder.classes_))

confusion_mat = confusion_matrix(y_test_true, y_test_pred)
confusion_mat_display = ConfusionMatrixDisplay(confusion_matrix=confusion_mat, display_labels=label_encoder.classes_)
confusion_mat_display.plot(cmap="Blues")
plt.title("Confusion Matrix")
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#         asta       1.00      1.00      1.00        21
#         budi       1.00      1.00      1.00         7
#        juned       1.00      1.00      1.00        10
#     shabrina       1.00      1.00      1.00        18
#
#     accuracy                           1.00        56
#    macro avg       1.00      1.00      1.00        56
# weighted avg       1.00      1.00      1.00        56

# %% [markdown]
# # **[5] Inference**

# %%
def predict_image(image_path):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    image = cv2.resize(image, IMAGE_SIZE)
    image_input = image.flatten().astype(np.float32) / 255.0
    image_input = np.expand_dims(image_input, axis=0)

    prediction = model.predict(image_input, verbose=0)
    label = label_encoder.inverse_transform([np.argmax(prediction)])[0]
    confidence = np.max(prediction)
    return label, confidence, image

n_samples = 10
rng = np.random.default_rng(SEED)
sample_indices = rng.choice(len(paths_test), size=n_samples, replace=False)

fig, axes = plt.subplots(2, 5, figsize=(15, 7))

for ax, idx in zip(axes.flatten(), sample_indices):
    image_path = paths_test[idx]
    true_label = label_encoder.inverse_transform([np.argmax(y_test[idx])])[0]

    pred_label, confidence, image = predict_image(image_path)
    is_correct = pred_label == true_label
    color = "green" if is_correct else "red"

    ax.imshow(image, cmap="gray")
    ax.axis("off")
    ax.set_title(f"True: {true_label}\nPred: {pred_label} ({confidence:.1%})",
                 color=color, fontsize=10)

plt.tight_layout()
plt.show()
